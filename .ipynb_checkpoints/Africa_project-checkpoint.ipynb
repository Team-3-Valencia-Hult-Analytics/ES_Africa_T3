# %% [markdown]
# # Python Final Project

# %%
# importing packages
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#Loading data
world_regions= pd.read_excel('WDIW_FDataset.xlsx') # index_col = 0) # index_col = 0 uses Country Code as index.

# Filtering Data
Africa_dataset = world_regions[world_regions['Cool Name'] == 'Jazz' ]

#### Africa_dataset.loc[:,["GDP (current US$)"]]  # code for row Access by .loc (label-based)

# Africa Head Analysis
Africa_dataset.head()
# Out:
#    Country Code  Country Name        Hult Region Cool Name  \
# 5           AGO        Angola  East/South Africa      Jazz
# 25          ZAF  South Africa  East/South Africa      Jazz
# 31          ETH      Ethiopia  East/South Africa      Jazz
# 44          KEN         Kenya  East/South Africa      Jazz
# 53          TZA      Tanzania  East/South Africa      Jazz
#
#     Access to electricity (% of population)  \
# 5                                 41.886230
# 25                                84.400000
# 31                                44.300000
# 44                                63.811470
# 53                                32.813332
#
#     Access to electricity, rural (% of rural population)  \
# 5                                                 NaN
# 25                                          66.885809
# 31                                          30.970686
# 44                                          57.570480
# 53                                          16.755115
#
#     Access to electricity, urban (% of urban population)  \
# 5                                           72.722191
# 25                                          93.482910
# 31                                          96.600000
# 44                                          81.066414
# 53                                          65.338348
#
#     Adolescent fertility rate (births per 1,000 women ages 15-19)  \
# 5                                             150.526
# 25                                             67.908
# 31                                             66.727
# 44                                             75.078
# 53                                            118.385
#
#     Age dependency ratio (% of working-age population)  \
# 5                                           96.820228
# 25                                          52.368040
# 31                                          80.958230
# 44                                          74.234598
# 53                                          88.324307
#
#     Age dependency ratio, old (% of working-age population)  ...  \
# 5                                            4.407194        ...
# 25                                           7.952359        ...
# 31                                           6.311516        ...
# 44                                           3.930915        ...
# 53                                           4.865662        ...
#
#     Poverty headcount ratio at national poverty lines (% of population)  \
# 5                                                 NaN
# 25                                                NaN
# 31                                                NaN
# 44                                                NaN
# 53                                                NaN
#
#     Prevalence of HIV, total (% of population ages 15-49)  \
# 5                                                 2.0
# 25                                               20.5
# 31                                                1.1
# 44                                                4.9
# 53                                                4.7
#
#     Prevalence of undernourishment (% of population)  \
# 5                                               25.0
# 25                                               6.2
# 31                                              20.6
# 44                                              29.4
# 53                                              30.7
#
#     Prevalence of underweight, weight for age (% of children under 5)  \
# 5                                                 NaN
# 25                                                NaN
# 31                                                NaN
# 44                                                NaN
# 53                                                NaN
#
#     Rural population (% of total population)  \
# 5                                     35.161
# 25                                    34.150
# 31                                    79.690
# 44                                    73.438
# 53                                    66.947
#
#     Services, value added (% of GDP)  Surface area (sq. km)  \
# 5                          46.762624              1246700.0
# 25                         61.025589              1219090.0
# 31                         36.638292              1104300.0
# 44                         41.981654               580370.0
# 53                         37.922620               947300.0
#
#     Tax revenue (% of GDP)  Urban population (% of total population)  \
# 5                 9.223777                                    64.839
# 25               26.966067                                    65.850
# 31                7.604892                                    20.310
# 44               15.679048                                    26.562
# 53               11.826565                                    33.053
#
#     Urban population growth (annual %)
# 5                             4.391957
# 25                            2.183711
# 31                            4.873831
# 44                            4.092288
# 53                            5.197784
#
# [5 rows x 67 columns]

# %%
# Identiy the number of missing values

# Val = Values

# Number of null values aggregated
null_val = Africa_dataset.isnull().agg('sum').sort_values(ascending = False)

# defining missing values
missing_val = null_val[null_val > 0]

# Display the missing values
print(missing_val)
# Out:
# Educational attainment, at least Master's or equivalent, population 25+, total (%) (cumulative)            22
# Literacy rate, youth total (% of people ages 15-24)                                                        22
# Educational attainment, at least Bachelor's or equivalent, population 25+, total (%) (cumulative)          22
# Educational attainment, at least completed upper secondary, population 25+, total (%) (cumulative)         22
# Educational attainment, Doctoral or equivalent, population 25+, total (%) (cumulative)                     22
# Prevalence of underweight, weight for age (% of children under 5)                                          22
# Educational attainment, at least completed post-secondary, population 25+, total (%) (cumulative)          22
# Educational attainment, at least completed short-cycle tertiary, population 25+, total (%) (cumulative)    22
# Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)         22
# Educational attainment, at least completed primary, population 25+ years, total (%) (cumulative)           22
# Literacy rate, adult total (% of people ages 15 and above)                                                 22
# GINI index (World Bank estimate)                                                                           21
# Births attended by skilled health staff (% of total)                                                       21
# Income share held by highest 20%                                                                           21
# Poverty headcount ratio at $1.90 a day (2011 PPP) (% of population)                                        21
# Income share held by third 20%                                                                             21
# Income share held by second 20%                                                                            21
# Income share held by lowest 20%                                                                            21
# Income share held by fourth 20%                                                                            21
# Poverty headcount ratio at $3.20 a day (2011 PPP) (% of population)                                        21
# Poverty headcount ratio at national poverty lines (% of population)                                        18
# Government expenditure on education, total (% of government expenditure)                                   15
# Tax revenue (% of GDP)                                                                                      6
# Population in the largest city (% of urban population)                                                      4
# Agriculture, forestry, and fishing, value added (% of GDP)                                                  4
# Industry (including construction), value added (% of GDP)                                                   4
# Prevalence of undernourishment (% of population)                                                            4
# Services, value added (% of GDP)                                                                            4
# Military expenditure (% of GDP)                                                                             3
# Merchandise trade (% of GDP)                                                                                3
# Access to electricity, rural (% of rural population)                                                        2
# Population density (people per sq. km of land area)                                                         2
# Armed forces personnel (% of total labor force)                                                             1
# Age dependency ratio, young (% of working-age population)                                                   1
# Age dependency ratio, old (% of working-age population)                                                     1
# Age dependency ratio (% of working-age population)                                                          1
# Urban population growth (annual %)                                                                          1
# Population, female                                                                                          1
# Population ages 15-64 (% of total population)                                                               1
# Population, total                                                                                           1
# Rural population (% of total population)                                                                    1
# Population growth (annual %)                                                                                1
# Urban population (% of total population)                                                                    1
# Surface area (sq. km)                                                                                       1
# Population ages 65 and above (% of total population)                                                        1
# Population, male                                                                                            1
# Population ages 0-14 (% of total population)                                                                1
# dtype: int64

# %% [markdown]
# ## Missing Values
# ### Finding Values
# #### Test set

# %%
# Africa

Africa = ['AGO','BWA','BDI','COG','DJI','ERI', 'SWZ','ETH','KEN','LSO','MDG', 
          'MWI','MOZ','NAM','RWA','SOM','ZAF','SSD','TZA','UGA','ZMB',
          'ZWE']

# Subset of Countr - dies
AfricaDf = Africa_dataset[Africa_dataset['Country Code'].isin(Africa)]

AfricaDf.rename(columns={"Country Name":"Country_Name","Employment in agriculture (% of total employment) (modeled ILO estimate)"
                         : "Emp_agriculture","Employment in industry (% of total employment) (modeled ILO estimate)"
                         : "Emp_industry","Employment in services (% of total employment) (modeled ILO estimate)"
                         : "Emp_services","GDP (current US$)":"GDP_USD","GDP growth (annual %)":"GDP_growth"}, inplace=True)

AfricaDf.head() #loc[:,["Emp_agriculture"]]
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:4238: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(**kwargs)
#    Country Code  Country_Name        Hult Region Cool Name  \
# 5           AGO        Angola  East/South Africa      Jazz
# 25          ZAF  South Africa  East/South Africa      Jazz
# 31          ETH      Ethiopia  East/South Africa      Jazz
# 44          KEN         Kenya  East/South Africa      Jazz
# 53          TZA      Tanzania  East/South Africa      Jazz
#
#     Access to electricity (% of population)  \
# 5                                 41.886230
# 25                                84.400000
# 31                                44.300000
# 44                                63.811470
# 53                                32.813332
#
#     Access to electricity, rural (% of rural population)  \
# 5                                                 NaN
# 25                                          66.885809
# 31                                          30.970686
# 44                                          57.570480
# 53                                          16.755115
#
#     Access to electricity, urban (% of urban population)  \
# 5                                           72.722191
# 25                                          93.482910
# 31                                          96.600000
# 44                                          81.066414
# 53                                          65.338348
#
#     Adolescent fertility rate (births per 1,000 women ages 15-19)  \
# 5                                             150.526
# 25                                             67.908
# 31                                             66.727
# 44                                             75.078
# 53                                            118.385
#
#     Age dependency ratio (% of working-age population)  \
# 5                                           96.820228
# 25                                          52.368040
# 31                                          80.958230
# 44                                          74.234598
# 53                                          88.324307
#
#     Age dependency ratio, old (% of working-age population)  ...  \
# 5                                            4.407194        ...
# 25                                           7.952359        ...
# 31                                           6.311516        ...
# 44                                           3.930915        ...
# 53                                           4.865662        ...
#
#     Poverty headcount ratio at national poverty lines (% of population)  \
# 5                                                 NaN
# 25                                                NaN
# 31                                                NaN
# 44                                                NaN
# 53                                                NaN
#
#     Prevalence of HIV, total (% of population ages 15-49)  \
# 5                                                 2.0
# 25                                               20.5
# 31                                                1.1
# 44                                                4.9
# 53                                                4.7
#
#     Prevalence of undernourishment (% of population)  \
# 5                                               25.0
# 25                                               6.2
# 31                                              20.6
# 44                                              29.4
# 53                                              30.7
#
#     Prevalence of underweight, weight for age (% of children under 5)  \
# 5                                                 NaN
# 25                                                NaN
# 31                                                NaN
# 44                                                NaN
# 53                                                NaN
#
#     Rural population (% of total population)  \
# 5                                     35.161
# 25                                    34.150
# 31                                    79.690
# 44                                    73.438
# 53                                    66.947
#
#     Services, value added (% of GDP)  Surface area (sq. km)  \
# 5                          46.762624              1246700.0
# 25                         61.025589              1219090.0
# 31                         36.638292              1104300.0
# 44                         41.981654               580370.0
# 53                         37.922620               947300.0
#
#     Tax revenue (% of GDP)  Urban population (% of total population)  \
# 5                 9.223777                                    64.839
# 25               26.966067                                    65.850
# 31                7.604892                                    20.310
# 44               15.679048                                    26.562
# 53               11.826565                                    33.053
#
#     Urban population growth (annual %)
# 5                             4.391957
# 25                            2.183711
# 31                            4.873831
# 44                            4.092288
# 53                            5.197784
#
# [5 rows x 67 columns]

# %%
# Checking missing values for Africa Data Set
AfricaT = AfricaDf.transpose()

AfricaT.columns = Africa

# mv = missing values

Africa_mv_sorted = (AfricaT.isnull().sum().sort_values(ascending = False) / len(AfricaT)) * 100

Africa_mv_sorted
# Out:
# ERI    65.671642
# SSD    43.283582
# SOM    41.791045
# BDI    37.313433
# SWZ    35.820896
# BWA    34.328358
# COG    34.328358
# MDG    34.328358
# ETH    32.835821
# TZA    32.835821
# NAM    32.835821
# MOZ    32.835821
# ZMB    32.835821
# LSO    32.835821
# ZWE    31.343284
# KEN    31.343284
# RWA    31.343284
# ZAF    31.343284
# UGA    31.343284
# MWI    31.343284
# DJI    22.388060
# dtype: float64

# %%
# Checking missing values per Column
# mc = Missing Cols
Africa_mc = AfricaDf.isnull().sum().sort_values(ascending = False)

# 68 indicators
print(f'Matrix Shape: {AfricaDf.shape}') 

# Indicators with 100% missing values (22 Missing Values)
print(Africa_mc[Africa_mc == 22])
# Out:
# Matrix Shape: (21, 67)
# Series([], dtype: int64)

# %%
# Indicators between 1 to 3 missing datapoints

Africa_mc[Africa_mc <= 3][Africa_mc > 0]
# Out:
# Military expenditure (% of GDP)                              3
# Merchandise trade (% of GDP)                                 3
# Population density (people per sq. km of land area)          2
# Armed forces personnel (% of total labor force)              1
# Age dependency ratio, young (% of working-age population)    1
# Age dependency ratio, old (% of working-age population)      1
# Age dependency ratio (% of working-age population)           1
# Access to electricity, rural (% of rural population)         1
# Urban population growth (annual %)                           1
# Population, female                                           1
# Population ages 15-64 (% of total population)                1
# Population, total                                            1
# Rural population (% of total population)                     1
# Population growth (annual %)                                 1
# Urban population (% of total population)                     1
# Surface area (sq. km)                                        1
# Population ages 65 and above (% of total population)         1
# Population, male                                             1
# Population ages 0-14 (% of total population)                 1
# dtype: int64

# %%
# Only one missing value
Africa_mc[Africa_mc >= 1 ][Africa_mc < 2]
# Out:
# Armed forces personnel (% of total labor force)              1
# Age dependency ratio, young (% of working-age population)    1
# Age dependency ratio, old (% of working-age population)      1
# Age dependency ratio (% of working-age population)           1
# Access to electricity, rural (% of rural population)         1
# Urban population growth (annual %)                           1
# Population, female                                           1
# Population ages 15-64 (% of total population)                1
# Population, total                                            1
# Rural population (% of total population)                     1
# Population growth (annual %)                                 1
# Urban population (% of total population)                     1
# Surface area (sq. km)                                        1
# Population ages 65 and above (% of total population)         1
# Population, male                                             1
# Population ages 0-14 (% of total population)                 1
# dtype: int64

# %%
# Subset indicators with at least 1 missing value. This is a boolean DataFrame
# mb = missing boolean
Africa_mb = AfricaDf[Africa_mc[Africa_mc >= 1].index].isnull().copy()


AfricaMissingbyCountry = AfricaDf[Africa_mb.columns.copy()]

# Created Country code column in order to add it as an index
AfricaMissingbyCountry.loc[:,'CountryCode'] = AfricaDf['Country Code'].copy()

# modified index to have the country code. Easier subsetting!
AfricaMissingbyCountry = AfricaMissingbyCountry.set_index('CountryCode').copy()

# The final dataframe contains the dataframe that has missing values 
AfricaMissingbyCountry
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:376: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
#              Educational attainment, at least Master's or equivalent, population 25+, total (%) (cumulative)  \
# CountryCode
# BWA                                                        NaN
# BDI                                                        NaN
# COG                                                        NaN
# DJI                                                        NaN
# ERI                                                        NaN
# SWZ                                                        NaN
# ETH                                                        NaN
# KEN                                                        NaN
# LSO                                                        NaN
# MDG                                                        NaN
# MWI                                                        NaN
# MOZ                                                        NaN
# NAM                                                        NaN
# RWA                                                        NaN
# SOM                                                        NaN
# ZAF                                                        NaN
# SSD                                                        NaN
# TZA                                                        NaN
# UGA                                                        NaN
# ZMB                                                        NaN
# ZWE                                                        NaN
#
#              Literacy rate, youth total (% of people ages 15-24)  \
# CountryCode
# BWA                                                        NaN
# BDI                                                        NaN
# COG                                                        NaN
# DJI                                                        NaN
# ERI                                                        NaN
# SWZ                                                        NaN
# ETH                                                        NaN
# KEN                                                        NaN
# LSO                                                        NaN
# MDG                                                        NaN
# MWI                                                        NaN
# MOZ                                                        NaN
# NAM                                                        NaN
# RWA                                                        NaN
# SOM                                                        NaN
# ZAF                                                        NaN
# SSD                                                        NaN
# TZA                                                        NaN
# UGA                                                        NaN
# ZMB                                                        NaN
# ZWE                                                        NaN
#
#              Educational attainment, at least Bachelor's or equivalent, population 25+, total (%) (cumulative)  \
# CountryCode
# BWA                                                        NaN
# BDI                                                        NaN
# COG                                                        NaN
# DJI                                                        NaN
# ERI                                                        NaN
# SWZ                                                        NaN
# ETH                                                        NaN
# KEN                                                        NaN
# LSO                                                        NaN
# MDG                                                        NaN
# MWI                                                        NaN
# MOZ                                                        NaN
# NAM                                                        NaN
# RWA                                                        NaN
# SOM                                                        NaN
# ZAF                                                        NaN
# SSD                                                        NaN
# TZA                                                        NaN
# UGA                                                        NaN
# ZMB                                                        NaN
# ZWE                                                        NaN
#
#              Educational attainment, at least completed upper secondary, population 25+, total (%) (cumulative)  \
# CountryCode
# BWA                                                        NaN
# BDI                                                        NaN
# COG                                                        NaN
# DJI                                                        NaN
# ERI                                                        NaN
# SWZ                                                        NaN
# ETH                                                        NaN
# KEN                                                        NaN
# LSO                                                        NaN
# MDG                                                        NaN
# MWI                                                        NaN
# MOZ                                                        NaN
# NAM                                                        NaN
# RWA                                                        NaN
# SOM                                                        NaN
# ZAF                                                        NaN
# SSD                                                        NaN
# TZA                                                        NaN
# UGA                                                        NaN
# ZMB                                                        NaN
# ZWE                                                        NaN
#
#              Educational attainment, Doctoral or equivalent, population 25+, total (%) (cumulative)  \
# CountryCode
# BWA                                                        NaN
# BDI                                                        NaN
# COG                                                        NaN
# DJI                                                        NaN
# ERI                                                        NaN
# SWZ                                                        NaN
# ETH                                                        NaN
# KEN                                                        NaN
# LSO                                                        NaN
# MDG                                                        NaN
# MWI                                                        NaN
# MOZ                                                        NaN
# NAM                                                        NaN
# RWA                                                        NaN
# SOM                                                        NaN
# ZAF                                                        NaN
# SSD                                                        NaN
# TZA                                                        NaN
# UGA                                                        NaN
# ZMB                                                        NaN
# ZWE                                                        NaN
#
#              Prevalence of underweight, weight for age (% of children under 5)  \
# CountryCode
# BWA                                                        NaN
# BDI                                                        NaN
# COG                                                        NaN
# DJI                                                        NaN
# ERI                                                        NaN
# SWZ                                                        NaN
# ETH                                                        NaN
# KEN                                                        NaN
# LSO                                                        NaN
# MDG                                                        NaN
# MWI                                                        NaN
# MOZ                                                        NaN
# NAM                                                        NaN
# RWA                                                        NaN
# SOM                                                        NaN
# ZAF                                                        NaN
# SSD                                                        NaN
# TZA                                                        NaN
# UGA                                                        NaN
# ZMB                                                        NaN
# ZWE                                                        NaN
#
#              Educational attainment, at least completed post-secondary, population 25+, total (%) (cumulative)  \
# CountryCode
# BWA                                                        NaN
# BDI                                                        NaN
# COG                                                        NaN
# DJI                                                        NaN
# ERI                                                        NaN
# SWZ                                                        NaN
# ETH                                                        NaN
# KEN                                                        NaN
# LSO                                                        NaN
# MDG                                                        NaN
# MWI                                                        NaN
# MOZ                                                        NaN
# NAM                                                        NaN
# RWA                                                        NaN
# SOM                                                        NaN
# ZAF                                                        NaN
# SSD                                                        NaN
# TZA                                                        NaN
# UGA                                                        NaN
# ZMB                                                        NaN
# ZWE                                                        NaN
#
#              Educational attainment, at least completed short-cycle tertiary, population 25+, total (%) (cumulative)  \
# CountryCode
# BWA                                                        NaN
# BDI                                                        NaN
# COG                                                        NaN
# DJI                                                        NaN
# ERI                                                        NaN
# SWZ                                                        NaN
# ETH                                                        NaN
# KEN                                                        NaN
# LSO                                                        NaN
# MDG                                                        NaN
# MWI                                                        NaN
# MOZ                                                        NaN
# NAM                                                        NaN
# RWA                                                        NaN
# SOM                                                        NaN
# ZAF                                                        NaN
# SSD                                                        NaN
# TZA                                                        NaN
# UGA                                                        NaN
# ZMB                                                        NaN
# ZWE                                                        NaN
#
#              Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)  \
# CountryCode
# BWA                                                        NaN
# BDI                                                        NaN
# COG                                                        NaN
# DJI                                                        NaN
# ERI                                                        NaN
# SWZ                                                        NaN
# ETH                                                        NaN
# KEN                                                        NaN
# LSO                                                        NaN
# MDG                                                        NaN
# MWI                                                        NaN
# MOZ                                                        NaN
# NAM                                                        NaN
# RWA                                                        NaN
# SOM                                                        NaN
# ZAF                                                        NaN
# SSD                                                        NaN
# TZA                                                        NaN
# UGA                                                        NaN
# ZMB                                                        NaN
# ZWE                                                        NaN
#
#              Educational attainment, at least completed primary, population 25+ years, total (%) (cumulative)  \
# CountryCode
# BWA                                                        NaN
# BDI                                                        NaN
# COG                                                        NaN
# DJI                                                        NaN
# ERI                                                        NaN
# SWZ                                                        NaN
# ETH                                                        NaN
# KEN                                                        NaN
# LSO                                                        NaN
# MDG                                                        NaN
# MWI                                                        NaN
# MOZ                                                        NaN
# NAM                                                        NaN
# RWA                                                        NaN
# SOM                                                        NaN
# ZAF                                                        NaN
# SSD                                                        NaN
# TZA                                                        NaN
# UGA                                                        NaN
# ZMB                                                        NaN
# ZWE                                                        NaN
#
#              ...  Population, female  \
# CountryCode  ...
# BWA          ...           1142634.0
# BDI          ...           5461521.0
# COG          ...           2559386.0
# DJI          ...            446702.0
# ERI          ...                 NaN
# SWZ          ...            577502.0
# ETH          ...          53185250.0
# KEN          ...          25271169.0
# LSO          ...           1061309.0
# MDG          ...          12818676.0
# MWI          ...           8960669.0
# MOZ          ...          14757711.0
# NAM          ...           1238986.0
# RWA          ...           6094885.0
# SOM          ...           7313284.0
# ZAF          ...          28883601.0
# SSD          ...           5451274.0
# TZA          ...          27367208.0
# UGA          ...          20916321.0
# ZMB          ...           8510888.0
# ZWE          ...           7459621.0
#
#              Population ages 15-64 (% of total population)  Population, total  \
# CountryCode
# BWA                                              61.474323          2205128.0
# BDI                                              52.257745         10827024.0
# COG                                              55.412640          5110702.0
# DJI                                              65.561451           944097.0
# ERI                                                    NaN                NaN
# SWZ                                              57.647681          1124753.0
# ETH                                              55.261371        106400024.0
# KEN                                              57.393882         50221473.0
# LSO                                              62.145966          2091412.0
# MDG                                              56.097504         25570540.0
# MWI                                              53.054109         17670260.0
# MOZ                                              52.142206         28649007.0
# NAM                                              59.448572          2402603.0
# RWA                                              57.014108         11980937.0
# SOM                                              50.393336         14589119.0
# ZAF                                              65.630562         57000451.0
# SSD                                              54.527406         10910759.0
# TZA                                              53.099890         54663906.0
# UGA                                              50.759757         41162465.0
# ZMB                                              52.503824         16853688.0
# ZWE                                              54.505941         14236745.0
#
#              Rural population (% of total population)  \
# CountryCode
# BWA                                            31.300
# BDI                                            87.294
# COG                                            33.541
# DJI                                            22.352
# ERI                                               NaN
# SWZ                                            76.375
# ETH                                            79.690
# KEN                                            73.438
# LSO                                            72.270
# MDG                                            63.478
# MWI                                            83.286
# MOZ                                            64.545
# NAM                                            50.995
# RWA                                            82.875
# SOM                                            55.609
# ZAF                                            34.150
# SSD                                            80.654
# TZA                                            66.947
# UGA                                            76.804
# ZMB                                            57.024
# ZWE                                            67.763
#
#              Population growth (annual %)  \
# CountryCode
# BWA                              2.070326
# BDI                              3.181368
# COG                              2.570630
# DJI                              1.599962
# ERI                                   NaN
# SWZ                              0.962068
# ETH                              2.663468
# KEN                              2.356813
# LSO                              0.787780
# MDG                              2.679883
# MWI                              2.666616
# MOZ                              2.900629
# NAM                              1.872154
# RWA                              2.639665
# SOM                              2.804769
# ZAF                              1.407741
# SSD                              0.719738
# TZA                              2.995388
# UGA                              3.749875
# ZMB                              2.951583
# ZWE                              1.460061
#
#              Urban population (% of total population)  Surface area (sq. km)  \
# CountryCode
# BWA                                            68.700               581730.0
# BDI                                            12.706                27830.0
# COG                                            66.459               342000.0
# DJI                                            77.648                23200.0
# ERI                                               NaN               117600.0
# SWZ                                            23.625                17360.0
# ETH                                            20.310              1104300.0
# KEN                                            26.562               580370.0
# LSO                                            27.730                30360.0
# MDG                                            36.522               587295.0
# MWI                                            16.714               118480.0
# MOZ                                            35.455               786380.0
# NAM                                            49.005               824290.0
# RWA                                            17.125                26340.0
# SOM                                            44.391               637660.0
# ZAF                                            65.850              1219090.0
# SSD                                            19.346                    NaN
# TZA                                            33.053               947300.0
# UGA                                            23.196               241550.0
# ZMB                                            42.976               752610.0
# ZWE                                            32.237               390760.0
#
#              Population ages 65 and above (% of total population)  \
# CountryCode
# BWA                                                   4.086836
# BDI                                                   2.186761
# COG                                                   2.643163
# DJI                                                   4.456524
# ERI                                                        NaN
# SWZ                                                   4.007895
# ETH                                                   3.487830
# KEN                                                   2.256106
# LSO                                                   4.872644
# MDG                                                   2.930184
# MWI                                                   2.649014
# MOZ                                                   2.898333
# NAM                                                   3.668892
# RWA                                                   2.849763
# SOM                                                   2.853684
# ZAF                                                   5.219179
# SSD                                                   3.415765
# TZA                                                   2.583661
# UGA                                                   1.920305
# ZMB                                                   2.084807
# ZWE                                                   2.896191
#
#              Population, male  Population ages 0-14 (% of total population)
# CountryCode
# BWA                 1062494.0                                     34.438841
# BDI                 5365503.0                                     45.555494
# COG                 2551316.0                                     41.944197
# DJI                  497395.0                                     29.982025
# ERI                       NaN                                           NaN
# SWZ                  547251.0                                     38.344424
# ETH                53214774.0                                     41.250798
# KEN                24950304.0                                     40.350012
# LSO                 1030103.0                                     32.981391
# MDG                12751864.0                                     40.972312
# MWI                 8709591.0                                     44.296877
# MOZ                13891296.0                                     44.959461
# NAM                 1163617.0                                     36.882537
# RWA                 5886052.0                                     40.136129
# SOM                 7275835.0                                     46.752980
# ZAF                28116850.0                                     29.150260
# SSD                 5459485.0                                     42.056830
# TZA                27296698.0                                     44.316449
# UGA                20246144.0                                     47.319938
# ZMB                 8342800.0                                     45.411369
# ZWE                 6777124.0                                     42.597868
#
# [21 rows x 47 columns]

# %% [markdown]
# ## Web Scraping (Test)

# %%
#UNCOMMENT (!PIP INSTALL) BEFORE RUNNING THIS CODE AND THEN COMMENT BACK AGAIN TO SPEED THE PROCESS
#!pip install world_bank_data --upgrade 

import world_bank_data as wb

# It's necessary to get the indicators code, this is different from the column names. 
    # E.g: Income share held by fourth 20% is coded as: SI.DST.04TH.20
    
missingIndicators = Africa_mc[Africa_mc >= 1].index.copy()

# Created empty dataframe with the column format that the API will return
    # We just need to append in a simple loop
indicatorsCodedMissing = pd.DataFrame(columns = ['name', 'unit', 'source', 'sourceNote', 'sourceOrganization', 'topics'])

# Loop to get the missing indicators and store the in the indicatorsCodedMissing data frame
for i in list(missingIndicators):
    indicatorsCodedMissing = indicatorsCodedMissing.append(wb.search_indicators(i))

# view the first the indicator names
print(f'{indicatorsCodedMissing.index[0:3]} \n')

indicatorsCodedMissing.head()
# Out:
# Index(['SI.DST.05TH.20', 'SI.DST.03RD.20', 'SI.DST.02ND.20'], dtype='object')
#                                             name unit  \
# SI.DST.05TH.20  Income share held by highest 20%
# SI.DST.03RD.20    Income share held by third 20%
# SI.DST.02ND.20   Income share held by second 20%
# SI.DST.FRST.20   Income share held by lowest 20%
# SI.DST.04TH.20   Income share held by fourth 20%
#
#                                       source  \
# SI.DST.05TH.20  World Development Indicators
# SI.DST.03RD.20  World Development Indicators
# SI.DST.02ND.20  World Development Indicators
# SI.DST.FRST.20  World Development Indicators
# SI.DST.04TH.20  World Development Indicators
#
#                                                        sourceNote  \
# SI.DST.05TH.20  Percentage share of income or consumption is t...
# SI.DST.03RD.20  Percentage share of income or consumption is t...
# SI.DST.02ND.20  Percentage share of income or consumption is t...
# SI.DST.FRST.20  Percentage share of income or consumption is t...
# SI.DST.04TH.20  Percentage share of income or consumption is t...
#
#                                                sourceOrganization  \
# SI.DST.05TH.20  World Bank, Development Research Group. Data a...
# SI.DST.03RD.20  World Bank, Development Research Group. Data a...
# SI.DST.02ND.20  World Bank, Development Research Group. Data a...
# SI.DST.FRST.20  World Bank, Development Research Group. Data a...
# SI.DST.04TH.20  World Bank, Development Research Group. Data a...
#
#                                      topics
# SI.DST.05TH.20                     Poverty
# SI.DST.03RD.20                     Poverty
# SI.DST.02ND.20                     Poverty
# SI.DST.FRST.20  Poverty ,Aid Effectiveness
# SI.DST.04TH.20                     Poverty

# %%
# Now we obtain the data for the specific countries that we need

#UNCOMMENT (!PIP INSTALL) BEFORE RUNNING THIS CODE AND THEN COMMENT BACK AGAIN TO SPEED THE PROCESS 
#!pip install wbdata

import wbdata
from datetime import datetime

# missingIndicators = AfricaheadMissingCols[AfricaheadMissingCols > 1] 

# The indicators argument of get_dataframe needs to be a dictionary with 
    # the codes (previous step) as the key and the new column names as the values (missing Indicators)
    # It will return the Data frame with all the years in the world bank 
    
keys = list(indicatorsCodedMissing.index)
values = list(missingIndicators) 

wbQueriedAfrica = wbdata.get_dataframe(indicators = dict(zip(keys,values)), country = Africa, convert_date = False)

wbQueriedAfrica.head()
# Out:
#                Educational attainment, at least Master's or equivalent, population 25+, total (%) (cumulative)  \
# country  date
# Botswana 1960                                                NaN
#          1961                                                NaN
#          1962                                                NaN
#          1963                                                NaN
#          1964                                                NaN
#
#                Literacy rate, youth total (% of people ages 15-24)  \
# country  date
# Botswana 1960                                                NaN
#          1961                                                NaN
#          1962                                                NaN
#          1963                                                NaN
#          1964                                                NaN
#
#                Educational attainment, at least Bachelor's or equivalent, population 25+, total (%) (cumulative)  \
# country  date
# Botswana 1960                                                NaN
#          1961                                                NaN
#          1962                                                NaN
#          1963                                                NaN
#          1964                                                NaN
#
#                Educational attainment, at least completed upper secondary, population 25+, total (%) (cumulative)  \
# country  date
# Botswana 1960                                                NaN
#          1961                                                NaN
#          1962                                                NaN
#          1963                                                NaN
#          1964                                                NaN
#
#                Educational attainment, Doctoral or equivalent, population 25+, total (%) (cumulative)  \
# country  date
# Botswana 1960                                                NaN
#          1961                                                NaN
#          1962                                                NaN
#          1963                                                NaN
#          1964                                                NaN
#
#                Prevalence of underweight, weight for age (% of children under 5)  \
# country  date
# Botswana 1960                                             9752.0
#          1961                                             9870.0
#          1962                                            10190.0
#          1963                                            10640.0
#          1964                                            11113.0
#
#                Educational attainment, at least completed post-secondary, population 25+, total (%) (cumulative)  \
# country  date
# Botswana 1960                                                NaN
#          1961                                                NaN
#          1962                                                NaN
#          1963                                                NaN
#          1964                                                NaN
#
#                Educational attainment, at least completed short-cycle tertiary, population 25+, total (%) (cumulative)  \
# country  date
# Botswana 1960                                             9778.0
#          1961                                             9658.0
#          1962                                            10148.0
#          1963                                            10421.0
#          1964                                            10714.0
#
#                Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)  \
# country  date
# Botswana 1960                                                NaN
#          1961                                                NaN
#          1962                                                NaN
#          1963                                                NaN
#          1964                                                NaN
#
#                Educational attainment, at least completed primary, population 25+ years, total (%) (cumulative)  \
# country  date
# Botswana 1960                                             9647.0
#          1961                                             9607.0
#          1962                                             9561.0
#          1963                                            10146.0
#          1964                                            10320.0
#
#                ...  Population, female  \
# country  date  ...
# Botswana 1960  ...              4861.0
#          1961  ...              4714.0
#          1962  ...              4587.0
#          1963  ...              4440.0
#          1964  ...              4490.0
#
#                Population ages 15-64 (% of total population)  \
# country  date
# Botswana 1960                                            NaN
#          1961                                            NaN
#          1962                                            NaN
#          1963                                            NaN
#          1964                                            NaN
#
#                Population, total  Rural population (% of total population)  \
# country  date
# Botswana 1960             4947.0                                       NaN
#          1961             4829.0                                       NaN
#          1962             4679.0                                       NaN
#          1963             4551.0                                       NaN
#          1964             4407.0                                       NaN
#
#                Population growth (annual %)  \
# country  date
# Botswana 1960                        4954.0
#          1961                        4913.0
#          1962                        4796.0
#          1963                        4646.0
#          1964                        4520.0
#
#                Urban population (% of total population)  \
# country  date
# Botswana 1960                                       NaN
#          1961                                       NaN
#          1962                                       NaN
#          1963                                       NaN
#          1964                                       NaN
#
#                Surface area (sq. km)  \
# country  date
# Botswana 1960                 4908.0
#          1961                 4914.0
#          1962                 4878.0
#          1963                 4764.0
#          1964                 4617.0
#
#                Population ages 65 and above (% of total population)  \
# country  date
# Botswana 1960                                                NaN
#          1961                                                NaN
#          1962                                                NaN
#          1963                                                NaN
#          1964                                                NaN
#
#                Population, male  Population ages 0-14 (% of total population)
# country  date
# Botswana 1960            4890.0                                           NaN
#          1961            4858.0                                           NaN
#          1962            4871.0                                           NaN
#          1963            4843.0                                           NaN
#          1964            4736.0                                           NaN
#
# [5 rows x 47 columns]

# %%
# Subseting  for a particular year

wbQueriedAfrica.sort_index(inplace=True)

# What is the total of missing values that there are per year 
for i in range(2010,2019,1):
    print('{} missing values out of {} for year {} '.format(wbQueriedAfrica.xs(str(i),level='date'). 
                                                            transpose().isnull().sum().sum(), # Calculates overall sum of null values
                                                            wbQueriedAfrica.shape[1] * len(wbQueriedAfrica.index.levels[0]), # Number of columns * number of countries = total possible missing values 
                                                            i) # ith year 
        )

# It seems that 2015 is the most non-missing updated info that we can obtain 

# data for 2015 is queried
wbQueriedAfrica2017 = wbQueriedAfrica.xs('2017',level='date')

# Printing the data frame to know the contents
wbQueriedAfrica2017

# saving it to excel
   
wbQueriedAfrica2017.to_excel('worldBank2017AfricaCountries.xlsx')  # This is commented so I don't overwrite by mistake the file
# Out:
# 91 missing values out of 987 for year 2010
# 111 missing values out of 987 for year 2011
# 132 missing values out of 987 for year 2012
# 132 missing values out of 987 for year 2013
# 557 missing values out of 987 for year 2014
# 122 missing values out of 987 for year 2015
# 552 missing values out of 987 for year 2016
# 562 missing values out of 987 for year 2017
# 567 missing values out of 987 for year 2018

# %% [markdown]
# ***
# <br><br><br><br><br>
# <h2>Anomaly Detection and Treatment: Outliers</h2>

# %%
#Subseting Data

#macro analysis by Jorge Betancourt

Africa_macro = AfricaDf[["Country Code","Country_Name","GDP_USD","GDP_growth",
                         "Emp_agriculture","Emp_industry","Emp_services"]]

Africa_macro.describe().round(2)
# Out:
#             GDP_USD  GDP_growth  Emp_agriculture  Emp_industry  Emp_services
# count  2.100000e+01       21.00            21.00         21.00         21.00
# mean   4.052962e+10        2.64            53.88         11.56         34.56
# std    7.778584e+10        3.51            22.44          6.31         16.85
# min    3.060000e+02       -5.20             5.22          2.13          6.01
# 25%    4.433664e+09        0.50            48.94          7.52         22.92
# 50%    1.265191e+10        3.74            62.86          8.25         28.93
# 75%    2.599503e+10        4.70            67.15         15.88         41.74
# max    3.492681e+11        9.50            91.86         24.48         71.48

# %%
# A  set of boxplots for the macro variables

#Defining the color for the outliers

dr = "darkred"

# GDP (current US$)
AfricaDf.boxplot(column = ['GDP_USD'],
                 vert          = False,
                 manage_ticks  = True, # deprecated
                 patch_artist  = False,
                 meanline      = True,
                 showmeans     = True,
                 return_type   = 'both',
                 notch         = True, 
                 sym           = '*', 
                 showfliers    = True, 
                 bootstrap     = 1000,
                 flierprops=dict(color= dr, markeredgecolor= dr),
                 figsize = (10,5))

plt.savefig('GDP USD_BoxPlot.png')
plt.suptitle('GDP (current US$)')
plt.tight_layout()
plt.show()

# GDP growth (annual %)
AfricaDf.boxplot(column = ['GDP_growth'],
                 vert          = False,
                 manage_ticks  = True, # deprecated
                 patch_artist  = False,
                 meanline      = True,
                 showmeans     = True,
                 return_type   = 'both',
                 notch         = True, 
                 sym           = '*', 
                 showfliers    = True, 
                 bootstrap     = 1000,
                 flierprops=dict(color= dr, markeredgecolor= dr),
                 figsize = (10,5))

plt.savefig('GDP growth_BoxPlot.png')
plt.suptitle('GDP growth (annual %)')
plt.tight_layout()
plt.show()

# Employment in Agriculture
AfricaDf.boxplot(column = ['Emp_agriculture'],
                 vert          = False,
                 manage_ticks  = True, # deprecated
                 patch_artist  = False,
                 meanline      = True,
                 showmeans     = True,
                 return_type   = 'both',
                 notch         = True, 
                 sym           = '*', 
                 showfliers    = True, 
                 bootstrap     = 1000,
                 flierprops=dict(color= dr, markeredgecolor= dr),
                 figsize = (10,5))

plt.savefig('Emplyment in Agriculture_BoxPlot.png')
plt.suptitle('Emplyment in Agriculture')
plt.tight_layout()
plt.show()


# Employment in industry
AfricaDf.boxplot(column = ['Emp_industry'],
                 vert          = False,
                 manage_ticks  = True, # deprecated
                 patch_artist  = False,
                 meanline      = True,
                 showmeans     = True,
                 return_type   = 'both',
                 notch         = True, 
                 sym           = '*', 
                 showfliers    = True, 
                 bootstrap     = 1000,
                 flierprops=dict(color= dr, markeredgecolor= dr),
                 figsize = (10,5))

plt.savefig('Employment in industry_BoxPlot.png')
plt.suptitle('Employment in industry')
plt.tight_layout()
plt.show()

# Employment in Services
AfricaDf.boxplot(column = ['Emp_services'],
                 vert          = False,
                 manage_ticks  = True, # deprecated
                 patch_artist  = False,
                 meanline      = True,
                 showmeans     = True,
                 return_type   = 'both',
                 notch         = True, 
                 sym           = '*', 
                 showfliers    = True, 
                 bootstrap     = 1000,
                 flierprops=dict(color= dr, markeredgecolor= dr),
                 figsize = (10,5))

plt.savefig('Employment in Services_BoxPlot.png')
plt.suptitle('Employment in Services')
plt.tight_layout()
plt.show()

# %%
## Session 14.3.2 ##

# Customizing with sns.distplot
plt.subplot(2, 2, 1)
sns.distplot(Africa_macro['GDP_USD'],
             bins = 'fd',
             color = 'goldenrod')


# labeling axis
plt.xlabel('GDP_USD')

########################################


plt.subplot(2,2, 2)
sns.distplot(Africa_macro['GDP_growth'],
             bins = 'fd',
             color = 'orange')


# labeling axis
plt.xlabel('GDP_growth')

# formatting and display
plt.tight_layout()
plt.savefig('GDP_histograms.png')
plt.show()

########################################

plt.subplot(2, 2, 1)
sns.distplot(Africa_macro['Emp_agriculture'],
             bins = 'fd',
             kde = False,
             rug = True,
             color = 'springgreen')

# labeling axis
plt.xlabel('Employement in agriculture')

########################################

plt.subplot(2, 2, 2)

sns.distplot(Africa_macro['Emp_industry'],
             bins = 'fd',
             kde = False,
             rug = True,
             color = 'cyan')

# labeling axis
plt.xlabel('Employment in Industry')

########################################


plt.subplot(2, 2, 3)
sns.distplot(Africa_macro['Emp_services'],
             kde = False,
             rug = True,
             color = 'navy')


# labeling axis
plt.xlabel('Employment in Services')


# formatting and display
plt.tight_layout()
plt.savefig('Employment sectors.png')
plt.show()

# %%
df_corr = Africa_macro.corr().round(2)

df_corr
# Out:
#                  GDP_USD  GDP_growth  Emp_agriculture  Emp_industry  \
# GDP_USD             1.00        0.05            -0.44          0.31
# GDP_growth          0.05        1.00             0.34         -0.43
# Emp_agriculture    -0.44        0.34             1.00         -0.92
# Emp_industry        0.31       -0.43            -0.92          1.00
# Emp_services        0.47       -0.30            -0.99          0.85
#
#                  Emp_services
# GDP_USD                  0.47
# GDP_growth              -0.30
# Emp_agriculture         -0.99
# Emp_industry             0.85
# Emp_services             1.00

# %%
sns.heatmap(data       = df_corr,
            cmap       = 'Blues',
            square     = True,
            annot      = False,
            linecolor  = 'black',
            linewidths = 0.5)


# saving the figure and displaying the plot

# reconfiguring the plot
bottom, top = plt.ylim() # discover the values for bottom and top
bottom += 0.5            # add 0.5 to the bottom
top -= 0.5               # subtract 0.5 from the top
plt.ylim(bottom, top)    # update the ylim(bottom, top) values

plt.savefig('Africa Employment Analysis Correlation Heatmap.png')
plt.show()

# %%
## Sample Solution S15.1.4 ##

# Using palplot to view a color scheme
sns.palplot(sns.color_palette("BrBG", n_colors=10))

# specifying plot size
fig, ax = plt.subplots(figsize=(10,10))


# creating a heatmap
sns.heatmap(df_corr,
            cmap = 'BrBG',
            square = False,
            annot = True,
            linecolor = 'white',
            linewidths = 0.5,
            cbar = True)

# reconfiguring the plot
bottom, top = plt.ylim() # discover the values for bottom and top
bottom += 0.5            # add 0.5 to the bottom
top -= 0.5               # subtract 0.5 from the top
plt.ylim(bottom, top)    # update the ylim(bottom, top) values

# saving the figure and displaying the plot
plt.savefig('Africa Employment Analysis Correlation Heatmap 2.png')
plt.show()

# %%
def sinplot(flip=1):
    x = np.linspace(0, 14, 100)
    for i in range(1, 7):
        plt.plot(x, np.sin(x + i * .5) * (7 - i) * flip)

sns.set_palette("husl")
sinplot()

# %%
x, y = np.random.multivariate_normal([0, 0], [[1, -.5], [-.5, 1]], size=300).T
cmap = sns.cubehelix_palette(light=1, as_cmap=True)
sns.kdeplot(x, y, cmap=cmap, shade=True);

pal = sns.dark_palette("palegreen", as_cmap=True)
sns.kdeplot(x, y, cmap=pal);

# %%
## Sample Solution S15.2.1 ##

# specifying plot size
fig, ax = plt.subplots(figsize=(10,10))


# carat and price
plt.scatter(x = 'GDP_growth',
            y = 'Emp_industry',
            alpha = 0.7,
            cmap = 'bwr',
            data = Africa_macro)


# additional formatting options
plt.xlabel('Carat Weight')
plt.ylabel('Price')
plt.grid(True)


# displaying the plot
plt.show()
