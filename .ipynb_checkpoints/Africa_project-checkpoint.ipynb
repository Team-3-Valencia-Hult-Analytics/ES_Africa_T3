# %% [markdown]
# # Python Final Project

# %%
# importing packages
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#Loading data
world_regions= pd.read_excel('WDIW_Dataset.xlsx') # index_col = 0) # index_col = 0 uses Country Code as index.

# Filtering Data
Africa_dataset = world_regions[world_regions['Cool Name'] == 'Jazz' ]

### africa.loc[["COG", ]] code for row Access by .loc (label-based)
#### africa.iloc[[2]] #code for  row Access by .iloc (index-based)

# Head Analysis
Africa_dataset.head()
# Out:
#    Country Code          Country Name        Hult Region Cool Name  \
# 25          BWA              Botswana  East/South Africa      Jazz
# 31          BDI               Burundi  East/South Africa      Jazz
# 44          COG  Congo, Repub. of the  East/South Africa      Jazz
# 53          DJI              Djibouti  East/South Africa      Jazz
# 61          ERI               Eritrea  East/South Africa      Jazz
#
#     Access to electricity (% of population)  \
# 25                                62.824947
# 31                                 9.300000
# 44                                66.214851
# 53                                60.200000
# 61                                48.423790
#
#     Access to electricity, rural (% of rural population)  \
# 25                                          24.264212
# 31                                           1.658409
# 44                                          24.180856
# 53                                          26.294945
# 61                                          30.188929
#
#     Access to electricity, urban (% of urban population)  \
# 25                                          80.393379
# 31                                          61.800000
# 44                                          87.428864
# 53                                          69.960000
# 61                                          76.504364
#
#     Adolescent fertility rate (births per 1,000 women ages 15-19)  \
# 25                                             46.061
# 31                                             55.590
# 44                                            112.229
# 53                                             18.841
# 61                                             52.553
#
#     Age dependency ratio (% of working-age population)  \
# 25                                          62.669557
# 31                                          91.359181
# 44                                          80.464234
# 53                                          52.528580
# 61                                                NaN
#
#     Age dependency ratio, old (% of working-age population)  ...  \
# 25                                           6.648038        ...
# 31                                           4.184565        ...
# 44                                           4.769957        ...
# 53                                           6.797487        ...
# 61                                                NaN        ...
#
#     Poverty headcount ratio at national poverty lines (% of population)  \
# 25                                                NaN
# 31                                                NaN
# 44                                                NaN
# 53                                               21.1
# 61                                                NaN
#
#     Prevalence of HIV, total (% of population ages 15-49)  \
# 25                                               20.7
# 31                                                1.1
# 44                                                2.7
# 53                                                1.2
# 61                                                0.7
#
#     Prevalence of undernourishment (% of population)  \
# 25                                              26.4
# 31                                               NaN
# 44                                              40.3
# 53                                              18.9
# 61                                               NaN
#
#     Prevalence of underweight, weight for age (% of children under 5)  \
# 25                                                NaN
# 31                                                NaN
# 44                                                NaN
# 53                                                NaN
# 61                                                NaN
#
#     Rural population (% of total population)  \
# 25                                    31.300
# 31                                    87.294
# 44                                    33.541
# 53                                    22.352
# 61                                       NaN
#
#     Services, value added (% of GDP)  Surface area (sq. km)  \
# 25                         59.112989               581730.0
# 31                               NaN                27830.0
# 44                         40.079352               342000.0
# 53                         71.886722                23200.0
# 61                               NaN               117600.0
#
#     Tax revenue (% of GDP)  Urban population (% of total population)  \
# 25               22.144134                                    68.700
# 31                     NaN                                    12.706
# 44                     NaN                                    66.459
# 53                     NaN                                    77.648
# 61                     NaN                                       NaN
#
#     Urban population growth (annual %)
# 25                            3.193041
# 31                            5.716012
# 44                            3.262154
# 53                            1.754559
# 61                                 NaN
#
# [5 rows x 67 columns]

# %%
# Val = Values

# Number of missing values

# Number of null values aggregated
null_val = Africa_dataset.isnull().agg('sum').sort_values(ascending = False)

# defining missing values
missing_val = null_val[null_val > 0]

# Display the missing values
print(missing_val)
# Out:
# Educational attainment, at least Bachelor's or equivalent, population 25+, total (%) (cumulative)          22
# Educational attainment, Doctoral or equivalent, population 25+, total (%) (cumulative)                     22
# Educational attainment, at least completed upper secondary, population 25+, total (%) (cumulative)         22
# Prevalence of underweight, weight for age (% of children under 5)                                          22
# Educational attainment, at least completed short-cycle tertiary, population 25+, total (%) (cumulative)    22
# Literacy rate, adult total (% of people ages 15 and above)                                                 22
# Literacy rate, youth total (% of people ages 15-24)                                                        22
# Educational attainment, at least completed primary, population 25+ years, total (%) (cumulative)           22
# Educational attainment, at least completed post-secondary, population 25+, total (%) (cumulative)          22
# Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)         22
# Educational attainment, at least Master's or equivalent, population 25+, total (%) (cumulative)            22
# GINI index (World Bank estimate)                                                                           21
# Income share held by fourth 20%                                                                            21
# Income share held by lowest 20%                                                                            21
# Income share held by second 20%                                                                            21
# Income share held by third 20%                                                                             21
# Income share held by highest 20%                                                                           21
# Poverty headcount ratio at $3.20 a day (2011 PPP) (% of population)                                        21
# Poverty headcount ratio at $1.90 a day (2011 PPP) (% of population)                                        21
# Births attended by skilled health staff (% of total)                                                       21
# Poverty headcount ratio at national poverty lines (% of population)                                        18
# Government expenditure on education, total (% of government expenditure)                                   15
# Tax revenue (% of GDP)                                                                                      6
# Services, value added (% of GDP)                                                                            4
# Prevalence of undernourishment (% of population)                                                            4
# Industry (including construction), value added (% of GDP)                                                   4
# Population in the largest city (% of urban population)                                                      4
# Agriculture, forestry, and fishing, value added (% of GDP)                                                  4
# Merchandise trade (% of GDP)                                                                                3
# Military expenditure (% of GDP)                                                                             3
# GDP growth (annual %)                                                                                       3
# Population density (people per sq. km of land area)                                                         2
# GDP (current US$)                                                                                           2
# Age dependency ratio, old (% of working-age population)                                                     1
# Age dependency ratio, young (% of working-age population)                                                   1
# Age dependency ratio (% of working-age population)                                                          1
# Access to electricity, rural (% of rural population)                                                        1
# Armed forces personnel (% of total labor force)                                                             1
# Urban population growth (annual %)                                                                          1
# Population ages 15-64 (% of total population)                                                               1
# Population ages 0-14 (% of total population)                                                                1
# Population, male                                                                                            1
# Population, female                                                                                          1
# Rural population (% of total population)                                                                    1
# Population growth (annual %)                                                                                1
# Population ages 65 and above (% of total population)                                                        1
# Population, total                                                                                           1
# Surface area (sq. km)                                                                                       1
# Urban population (% of total population)                                                                    1
# dtype: int64

# %% [markdown]
# ## Missing Values
# ### Finding Values
# #### Test set

# %%
# Africa

Africa = ['BWA','BDI','COG','DJI','ERI', 'SWZ','ETH','KEN','LSO','MDG', 
          'MWI','MOZ','NAM','RWA','SOM','ZAF','SSD','TZA','TGO','UGA', 
         'ZMB','ZWE']

# Subset of Countr - dies
AfricaDf = Africa_dataset[Africa_dataset['Country Code'].isin(Africa)]

# %%
# Checking missing values for Africa Data Set
AfricaT = AfricaDf.transpose()

AfricaT.columns = Africa

# mv = missing values

Africa_mv_sorted = (AfricaT.isnull().sum().sort_values(ascending = False) / len(AfricaT)) * 100

Africa_mv_sorted
# Out:
# ERI    68.656716
# SSD    46.268657
# SOM    43.283582
# BDI    37.313433
# SWZ    35.820896
# BWA    34.328358
# COG    34.328358
# MDG    34.328358
# ETH    32.835821
# TGO    32.835821
# TZA    32.835821
# NAM    32.835821
# MOZ    32.835821
# ZMB    32.835821
# LSO    32.835821
# ZWE    31.343284
# KEN    31.343284
# RWA    31.343284
# ZAF    31.343284
# UGA    31.343284
# MWI    31.343284
# DJI    22.388060
# dtype: float64

# %%
# Checking missing values per Column
# mc = Missing Cols
Africa_mc = AfricaDf.isnull().sum().sort_values(ascending = False)

# 68 indicators
print(f'Matrix Shape: {AfricaDf.shape}') 

# Indicators with 100% missing values (22 Missing Values)
print(Africa_mc[Africa_mc == 22])
# Out:
# Matrix Shape: (22, 67)
# Educational attainment, at least Bachelor's or equivalent, population 25+, total (%) (cumulative)          22
# Educational attainment, Doctoral or equivalent, population 25+, total (%) (cumulative)                     22
# Educational attainment, at least completed upper secondary, population 25+, total (%) (cumulative)         22
# Prevalence of underweight, weight for age (% of children under 5)                                          22
# Educational attainment, at least completed short-cycle tertiary, population 25+, total (%) (cumulative)    22
# Literacy rate, adult total (% of people ages 15 and above)                                                 22
# Literacy rate, youth total (% of people ages 15-24)                                                        22
# Educational attainment, at least completed primary, population 25+ years, total (%) (cumulative)           22
# Educational attainment, at least completed post-secondary, population 25+, total (%) (cumulative)          22
# Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)         22
# Educational attainment, at least Master's or equivalent, population 25+, total (%) (cumulative)            22
# dtype: int64

# %%
# Indicators between 1 to 3 missing datapoints

Africa_mc[Africa_mc <= 3][Africa_mc > 0]
# Out:
# Merchandise trade (% of GDP)                                 3
# Military expenditure (% of GDP)                              3
# GDP growth (annual %)                                        3
# Population density (people per sq. km of land area)          2
# GDP (current US$)                                            2
# Age dependency ratio, old (% of working-age population)      1
# Age dependency ratio, young (% of working-age population)    1
# Age dependency ratio (% of working-age population)           1
# Access to electricity, rural (% of rural population)         1
# Armed forces personnel (% of total labor force)              1
# Urban population growth (annual %)                           1
# Population ages 15-64 (% of total population)                1
# Population ages 0-14 (% of total population)                 1
# Population, male                                             1
# Population, female                                           1
# Rural population (% of total population)                     1
# Population growth (annual %)                                 1
# Population ages 65 and above (% of total population)         1
# Population, total                                            1
# Surface area (sq. km)                                        1
# Urban population (% of total population)                     1
# dtype: int64

# %%
# Only one missing value
Africa_mc[Africa_mc >= 1 ][Africa_mc < 2]
# Out:
# Age dependency ratio, old (% of working-age population)      1
# Age dependency ratio, young (% of working-age population)    1
# Age dependency ratio (% of working-age population)           1
# Access to electricity, rural (% of rural population)         1
# Armed forces personnel (% of total labor force)              1
# Urban population growth (annual %)                           1
# Population ages 15-64 (% of total population)                1
# Population ages 0-14 (% of total population)                 1
# Population, male                                             1
# Population, female                                           1
# Rural population (% of total population)                     1
# Population growth (annual %)                                 1
# Population ages 65 and above (% of total population)         1
# Population, total                                            1
# Surface area (sq. km)                                        1
# Urban population (% of total population)                     1
# dtype: int64

# %%
# Subset indicators with at least 1 missing value. This is a boolean DataFrame
# mb = missing boolean
Africa_mb = AfricaDf[Africa_mc[Africa_mc >= 1].index].isnull().copy()


AfricaMissingbyCountry = AfricaDf[Africa_mb.columns.copy()]

# Created Country code column in order to add it as an index
AfricaMissingbyCountry.loc[:,'CountryCode'] = AfricaDf['Country Code'].copy()

# modified index to have the country code. Easier subsetting!
AfricaMissingbyCountry = AfricaMissingbyCountry.set_index('CountryCode').copy()

# The final dataframe contains the dataframe that has missing values 
AfricaMissingbyCountry
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:376: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
#              Educational attainment, at least Bachelor's or equivalent, population 25+, total (%) (cumulative)  \
# CountryCode
# BWA                                                        NaN
# BDI                                                        NaN
# COG                                                        NaN
# DJI                                                        NaN
# ERI                                                        NaN
# SWZ                                                        NaN
# ETH                                                        NaN
# KEN                                                        NaN
# LSO                                                        NaN
# MDG                                                        NaN
# MWI                                                        NaN
# MOZ                                                        NaN
# NAM                                                        NaN
# RWA                                                        NaN
# SOM                                                        NaN
# ZAF                                                        NaN
# SSD                                                        NaN
# TZA                                                        NaN
# TGO                                                        NaN
# UGA                                                        NaN
# ZMB                                                        NaN
# ZWE                                                        NaN
#
#              Educational attainment, Doctoral or equivalent, population 25+, total (%) (cumulative)  \
# CountryCode
# BWA                                                        NaN
# BDI                                                        NaN
# COG                                                        NaN
# DJI                                                        NaN
# ERI                                                        NaN
# SWZ                                                        NaN
# ETH                                                        NaN
# KEN                                                        NaN
# LSO                                                        NaN
# MDG                                                        NaN
# MWI                                                        NaN
# MOZ                                                        NaN
# NAM                                                        NaN
# RWA                                                        NaN
# SOM                                                        NaN
# ZAF                                                        NaN
# SSD                                                        NaN
# TZA                                                        NaN
# TGO                                                        NaN
# UGA                                                        NaN
# ZMB                                                        NaN
# ZWE                                                        NaN
#
#              Educational attainment, at least completed upper secondary, population 25+, total (%) (cumulative)  \
# CountryCode
# BWA                                                        NaN
# BDI                                                        NaN
# COG                                                        NaN
# DJI                                                        NaN
# ERI                                                        NaN
# SWZ                                                        NaN
# ETH                                                        NaN
# KEN                                                        NaN
# LSO                                                        NaN
# MDG                                                        NaN
# MWI                                                        NaN
# MOZ                                                        NaN
# NAM                                                        NaN
# RWA                                                        NaN
# SOM                                                        NaN
# ZAF                                                        NaN
# SSD                                                        NaN
# TZA                                                        NaN
# TGO                                                        NaN
# UGA                                                        NaN
# ZMB                                                        NaN
# ZWE                                                        NaN
#
#              Prevalence of underweight, weight for age (% of children under 5)  \
# CountryCode
# BWA                                                        NaN
# BDI                                                        NaN
# COG                                                        NaN
# DJI                                                        NaN
# ERI                                                        NaN
# SWZ                                                        NaN
# ETH                                                        NaN
# KEN                                                        NaN
# LSO                                                        NaN
# MDG                                                        NaN
# MWI                                                        NaN
# MOZ                                                        NaN
# NAM                                                        NaN
# RWA                                                        NaN
# SOM                                                        NaN
# ZAF                                                        NaN
# SSD                                                        NaN
# TZA                                                        NaN
# TGO                                                        NaN
# UGA                                                        NaN
# ZMB                                                        NaN
# ZWE                                                        NaN
#
#              Educational attainment, at least completed short-cycle tertiary, population 25+, total (%) (cumulative)  \
# CountryCode
# BWA                                                        NaN
# BDI                                                        NaN
# COG                                                        NaN
# DJI                                                        NaN
# ERI                                                        NaN
# SWZ                                                        NaN
# ETH                                                        NaN
# KEN                                                        NaN
# LSO                                                        NaN
# MDG                                                        NaN
# MWI                                                        NaN
# MOZ                                                        NaN
# NAM                                                        NaN
# RWA                                                        NaN
# SOM                                                        NaN
# ZAF                                                        NaN
# SSD                                                        NaN
# TZA                                                        NaN
# TGO                                                        NaN
# UGA                                                        NaN
# ZMB                                                        NaN
# ZWE                                                        NaN
#
#              Literacy rate, adult total (% of people ages 15 and above)  \
# CountryCode
# BWA                                                        NaN
# BDI                                                        NaN
# COG                                                        NaN
# DJI                                                        NaN
# ERI                                                        NaN
# SWZ                                                        NaN
# ETH                                                        NaN
# KEN                                                        NaN
# LSO                                                        NaN
# MDG                                                        NaN
# MWI                                                        NaN
# MOZ                                                        NaN
# NAM                                                        NaN
# RWA                                                        NaN
# SOM                                                        NaN
# ZAF                                                        NaN
# SSD                                                        NaN
# TZA                                                        NaN
# TGO                                                        NaN
# UGA                                                        NaN
# ZMB                                                        NaN
# ZWE                                                        NaN
#
#              Literacy rate, youth total (% of people ages 15-24)  \
# CountryCode
# BWA                                                        NaN
# BDI                                                        NaN
# COG                                                        NaN
# DJI                                                        NaN
# ERI                                                        NaN
# SWZ                                                        NaN
# ETH                                                        NaN
# KEN                                                        NaN
# LSO                                                        NaN
# MDG                                                        NaN
# MWI                                                        NaN
# MOZ                                                        NaN
# NAM                                                        NaN
# RWA                                                        NaN
# SOM                                                        NaN
# ZAF                                                        NaN
# SSD                                                        NaN
# TZA                                                        NaN
# TGO                                                        NaN
# UGA                                                        NaN
# ZMB                                                        NaN
# ZWE                                                        NaN
#
#              Educational attainment, at least completed primary, population 25+ years, total (%) (cumulative)  \
# CountryCode
# BWA                                                        NaN
# BDI                                                        NaN
# COG                                                        NaN
# DJI                                                        NaN
# ERI                                                        NaN
# SWZ                                                        NaN
# ETH                                                        NaN
# KEN                                                        NaN
# LSO                                                        NaN
# MDG                                                        NaN
# MWI                                                        NaN
# MOZ                                                        NaN
# NAM                                                        NaN
# RWA                                                        NaN
# SOM                                                        NaN
# ZAF                                                        NaN
# SSD                                                        NaN
# TZA                                                        NaN
# TGO                                                        NaN
# UGA                                                        NaN
# ZMB                                                        NaN
# ZWE                                                        NaN
#
#              Educational attainment, at least completed post-secondary, population 25+, total (%) (cumulative)  \
# CountryCode
# BWA                                                        NaN
# BDI                                                        NaN
# COG                                                        NaN
# DJI                                                        NaN
# ERI                                                        NaN
# SWZ                                                        NaN
# ETH                                                        NaN
# KEN                                                        NaN
# LSO                                                        NaN
# MDG                                                        NaN
# MWI                                                        NaN
# MOZ                                                        NaN
# NAM                                                        NaN
# RWA                                                        NaN
# SOM                                                        NaN
# ZAF                                                        NaN
# SSD                                                        NaN
# TZA                                                        NaN
# TGO                                                        NaN
# UGA                                                        NaN
# ZMB                                                        NaN
# ZWE                                                        NaN
#
#              Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)  \
# CountryCode
# BWA                                                        NaN
# BDI                                                        NaN
# COG                                                        NaN
# DJI                                                        NaN
# ERI                                                        NaN
# SWZ                                                        NaN
# ETH                                                        NaN
# KEN                                                        NaN
# LSO                                                        NaN
# MDG                                                        NaN
# MWI                                                        NaN
# MOZ                                                        NaN
# NAM                                                        NaN
# RWA                                                        NaN
# SOM                                                        NaN
# ZAF                                                        NaN
# SSD                                                        NaN
# TZA                                                        NaN
# TGO                                                        NaN
# UGA                                                        NaN
# ZMB                                                        NaN
# ZWE                                                        NaN
#
#              ...  Population ages 15-64 (% of total population)  \
# CountryCode  ...
# BWA          ...                                      61.474323
# BDI          ...                                      52.257745
# COG          ...                                      55.412640
# DJI          ...                                      65.561451
# ERI          ...                                            NaN
# SWZ          ...                                      57.647681
# ETH          ...                                      55.261371
# KEN          ...                                      57.393882
# LSO          ...                                      62.145966
# MDG          ...                                      56.097504
# MWI          ...                                      53.054109
# MOZ          ...                                      52.142206
# NAM          ...                                      59.448572
# RWA          ...                                      57.014108
# SOM          ...                                      50.393336
# ZAF          ...                                      65.630562
# SSD          ...                                      54.527406
# TZA          ...                                      53.099890
# TGO          ...                                      55.512196
# UGA          ...                                      50.759757
# ZMB          ...                                      52.503824
# ZWE          ...                                      54.505941
#
#              Population ages 0-14 (% of total population)  Population, male  \
# CountryCode
# BWA                                             34.438841         1062494.0
# BDI                                             45.555494         5365503.0
# COG                                             41.944197         2551316.0
# DJI                                             29.982025          497395.0
# ERI                                                   NaN               NaN
# SWZ                                             38.344424          547251.0
# ETH                                             41.250798        53214774.0
# KEN                                             40.350012        24950304.0
# LSO                                             32.981391         1030103.0
# MDG                                             40.972312        12751864.0
# MWI                                             44.296877         8709591.0
# MOZ                                             44.959461        13891296.0
# NAM                                             36.882537         1163617.0
# RWA                                             40.136129         5886052.0
# SOM                                             46.752980         7275835.0
# ZAF                                             29.150260        28116850.0
# SSD                                             42.056830         5459485.0
# TZA                                             44.316449        27296698.0
# TGO                                             41.637576         3827461.0
# UGA                                             47.319938        20246144.0
# ZMB                                             45.411369         8342800.0
# ZWE                                             42.597868         6777124.0
#
#              Population, female  Rural population (% of total population)  \
# CountryCode
# BWA                   1142634.0                                    31.300
# BDI                   5461521.0                                    87.294
# COG                   2559386.0                                    33.541
# DJI                    446702.0                                    22.352
# ERI                         NaN                                       NaN
# SWZ                    577502.0                                    76.375
# ETH                  53185250.0                                    79.690
# KEN                  25271169.0                                    73.438
# LSO                   1061309.0                                    72.270
# MDG                  12818676.0                                    63.478
# MWI                   8960669.0                                    83.286
# MOZ                  14757711.0                                    64.545
# NAM                   1238986.0                                    50.995
# RWA                   6094885.0                                    82.875
# SOM                   7313284.0                                    55.609
# ZAF                  28883601.0                                    34.150
# SSD                   5451274.0                                    80.654
# TZA                  27367208.0                                    66.947
# TGO                   3871014.0                                    58.838
# UGA                  20916321.0                                    76.804
# ZMB                   8510888.0                                    57.024
# ZWE                   7459621.0                                    67.763
#
#              Population growth (annual %)  \
# CountryCode
# BWA                              2.070326
# BDI                              3.181368
# COG                              2.570630
# DJI                              1.599962
# ERI                                   NaN
# SWZ                              0.962068
# ETH                              2.663468
# KEN                              2.356813
# LSO                              0.787780
# MDG                              2.679883
# MWI                              2.666616
# MOZ                              2.900629
# NAM                              1.872154
# RWA                              2.639665
# SOM                              2.804769
# ZAF                              1.407741
# SSD                              0.719738
# TZA                              2.995388
# TGO                              2.479318
# UGA                              3.749875
# ZMB                              2.951583
# ZWE                              1.460061
#
#              Population ages 65 and above (% of total population)  \
# CountryCode
# BWA                                                   4.086836
# BDI                                                   2.186761
# COG                                                   2.643163
# DJI                                                   4.456524
# ERI                                                        NaN
# SWZ                                                   4.007895
# ETH                                                   3.487830
# KEN                                                   2.256106
# LSO                                                   4.872644
# MDG                                                   2.930184
# MWI                                                   2.649014
# MOZ                                                   2.898333
# NAM                                                   3.668892
# RWA                                                   2.849763
# SOM                                                   2.853684
# ZAF                                                   5.219179
# SSD                                                   3.415765
# TZA                                                   2.583661
# TGO                                                   2.850227
# UGA                                                   1.920305
# ZMB                                                   2.084807
# ZWE                                                   2.896191
#
#              Population, total  Surface area (sq. km)  \
# CountryCode
# BWA                  2205128.0               581730.0
# BDI                 10827024.0                27830.0
# COG                  5110702.0               342000.0
# DJI                   944097.0                23200.0
# ERI                        NaN               117600.0
# SWZ                  1124753.0                17360.0
# ETH                106400024.0              1104300.0
# KEN                 50221473.0               580370.0
# LSO                  2091412.0                30360.0
# MDG                 25570540.0               587295.0
# MWI                 17670260.0               118480.0
# MOZ                 28649007.0               786380.0
# NAM                  2402603.0               824290.0
# RWA                 11980937.0                26340.0
# SOM                 14589119.0               637660.0
# ZAF                 57000451.0              1219090.0
# SSD                 10910759.0                    NaN
# TZA                 54663906.0               947300.0
# TGO                  7698475.0                56790.0
# UGA                 41162465.0               241550.0
# ZMB                 16853688.0               752610.0
# ZWE                 14236745.0               390760.0
#
#              Urban population (% of total population)
# CountryCode
# BWA                                            68.700
# BDI                                            12.706
# COG                                            66.459
# DJI                                            77.648
# ERI                                               NaN
# SWZ                                            23.625
# ETH                                            20.310
# KEN                                            26.562
# LSO                                            27.730
# MDG                                            36.522
# MWI                                            16.714
# MOZ                                            35.455
# NAM                                            49.005
# RWA                                            17.125
# SOM                                            44.391
# ZAF                                            65.850
# SSD                                            19.346
# TZA                                            33.053
# TGO                                            41.162
# UGA                                            23.196
# ZMB                                            42.976
# ZWE                                            32.237
#
# [22 rows x 49 columns]

# %% [markdown]
# ## Web Scraping (Test)

# %%
#UNCOMMENT (!PIP INSTALL) BEFORE RUNNING THIS CODE AND THEN COMMENT BACK AGAIN TO SPEED THE PROCESS
#!pip install world_bank_data --upgrade 

import world_bank_data as wb

# It's necessary to get the indicators code, this is different from the column names. 
    # E.g: Income share held by fourth 20% is coded as: SI.DST.04TH.20
    
missingIndicators = Africa_mc[Africa_mc >= 1].index.copy()

# Created empty dataframe with the column format that the API will return
    # We just need to append in a simple loop
indicatorsCodedMissing = pd.DataFrame(columns = ['name', 'unit', 'source', 'sourceNote', 'sourceOrganization', 'topics'])

# Loop to get the missing indicators and store the in the indicatorsCodedMissing data frame
for i in list(missingIndicators):
    indicatorsCodedMissing = indicatorsCodedMissing.append(wb.search_indicators(i))

# view the first the indicator names
print(f'{indicatorsCodedMissing.index[0:3]} \n')

indicatorsCodedMissing.head()
# Out:
# Index(['SI.DST.04TH.20', 'SI.DST.FRST.20', 'SI.DST.02ND.20'], dtype='object')
#                                             name unit  \
# SI.DST.04TH.20   Income share held by fourth 20%
# SI.DST.FRST.20   Income share held by lowest 20%
# SI.DST.02ND.20   Income share held by second 20%
# SI.DST.03RD.20    Income share held by third 20%
# SI.DST.05TH.20  Income share held by highest 20%
#
#                                       source  \
# SI.DST.04TH.20  World Development Indicators
# SI.DST.FRST.20  World Development Indicators
# SI.DST.02ND.20  World Development Indicators
# SI.DST.03RD.20  World Development Indicators
# SI.DST.05TH.20  World Development Indicators
#
#                                                        sourceNote  \
# SI.DST.04TH.20  Percentage share of income or consumption is t...
# SI.DST.FRST.20  Percentage share of income or consumption is t...
# SI.DST.02ND.20  Percentage share of income or consumption is t...
# SI.DST.03RD.20  Percentage share of income or consumption is t...
# SI.DST.05TH.20  Percentage share of income or consumption is t...
#
#                                                sourceOrganization  \
# SI.DST.04TH.20  World Bank, Development Research Group. Data a...
# SI.DST.FRST.20  World Bank, Development Research Group. Data a...
# SI.DST.02ND.20  World Bank, Development Research Group. Data a...
# SI.DST.03RD.20  World Bank, Development Research Group. Data a...
# SI.DST.05TH.20  World Bank, Development Research Group. Data a...
#
#                                      topics
# SI.DST.04TH.20                     Poverty
# SI.DST.FRST.20  Poverty ,Aid Effectiveness
# SI.DST.02ND.20                     Poverty
# SI.DST.03RD.20                     Poverty
# SI.DST.05TH.20                     Poverty

# %%
# Now we obtain the data for the specific countries that we need

#UNCOMMENT (!PIP INSTALL) BEFORE RUNNING THIS CODE AND THEN COMMENT BACK AGAIN TO SPEED THE PROCESS 
#!pip install wbdata

import wbdata
from datetime import datetime

# missingIndicators = AfricaheadMissingCols[AfricaheadMissingCols > 1] 

# The indicators argument of get_dataframe needs to be a dictionary with 
    # the codes (previous step) as the key and the new column names as the values (missing Indicators)
    # It will return the Data frame with all the years in the world bank 
    
keys = list(indicatorsCodedMissing.index)
values = list(missingIndicators) 

wbQueriedAfrica = wbdata.get_dataframe(indicators = dict(zip(keys,values)), country = Africa, convert_date = False)

wbQueriedAfrica.head()
# Out:
#                Educational attainment, at least Bachelor's or equivalent, population 25+, total (%) (cumulative)  \
# country  date
# Botswana 1960                                                NaN
#          1961                                                NaN
#          1962                                                NaN
#          1963                                                NaN
#          1964                                                NaN
#
#                Educational attainment, Doctoral or equivalent, population 25+, total (%) (cumulative)  \
# country  date
# Botswana 1960                                                NaN
#          1961                                                NaN
#          1962                                                NaN
#          1963                                                NaN
#          1964                                                NaN
#
#                Educational attainment, at least completed upper secondary, population 25+, total (%) (cumulative)  \
# country  date
# Botswana 1960                                                NaN
#          1961                                                NaN
#          1962                                                NaN
#          1963                                                NaN
#          1964                                                NaN
#
#                Prevalence of underweight, weight for age (% of children under 5)  \
# country  date
# Botswana 1960                                                NaN
#          1961                                                NaN
#          1962                                                NaN
#          1963                                                NaN
#          1964                                                NaN
#
#                Educational attainment, at least completed short-cycle tertiary, population 25+, total (%) (cumulative)  \
# country  date
# Botswana 1960                                                NaN
#          1961                                                NaN
#          1962                                                NaN
#          1963                                                NaN
#          1964                                                NaN
#
#                Literacy rate, adult total (% of people ages 15 and above)  \
# country  date
# Botswana 1960                                             9963.0
#          1961                                            10090.0
#          1962                                            10420.0
#          1963                                            10877.0
#          1964                                            11346.0
#
#                Literacy rate, youth total (% of people ages 15-24)  \
# country  date
# Botswana 1960                                             9940.0
#          1961                                             9848.0
#          1962                                            10335.0
#          1963                                            10620.0
#          1964                                            10916.0
#
#                Educational attainment, at least completed primary, population 25+ years, total (%) (cumulative)  \
# country  date
# Botswana 1960                                             9768.0
#          1961                                             9754.0
#          1962                                             9735.0
#          1963                                            10311.0
#          1964                                            10493.0
#
#                Educational attainment, at least completed post-secondary, population 25+, total (%) (cumulative)  \
# country  date
# Botswana 1960                                             9470.0
#          1961                                             9544.0
#          1962                                             9570.0
#          1963                                             9622.0
#          1964                                            10074.0
#
#                Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)  \
# country  date
# Botswana 1960                                             9069.0
#          1961                                             9236.0
#          1962                                             9322.0
#          1963                                             9385.0
#          1964                                             9510.0
#
#                ...  Population ages 15-64 (% of total population)  \
# country  date  ...
# Botswana 1960  ...                                         9647.0
#          1961  ...                                         9607.0
#          1962  ...                                         9561.0
#          1963  ...                                        10146.0
#          1964  ...                                        10320.0
#
#                Population ages 0-14 (% of total population)  Population, male  \
# country  date
# Botswana 1960                                           NaN            9382.0
#          1961                                           NaN            9434.0
#          1962                                           NaN            9434.0
#          1963                                           NaN            9465.0
#          1964                                           NaN            9929.0
#
#                Population, female  Rural population (% of total population)  \
# country  date
# Botswana 1960                 NaN                                    9008.0
#          1961                 NaN                                    9157.0
#          1962                 NaN                                    9220.0
#          1963                 NaN                                    9262.0
#          1964                 NaN                                    9380.0
#
#                Population growth (annual %)  \
# country  date
# Botswana 1960                           NaN
#          1961                           NaN
#          1962                           NaN
#          1963                           NaN
#          1964                           NaN
#
#                Population ages 65 and above (% of total population)  \
# country  date
# Botswana 1960                                             8547.0
#          1961                                             8793.0
#          1962                                             8929.0
#          1963                                             9006.0
#          1964                                             9101.0
#
#                Population, total  Surface area (sq. km)  \
# country  date
# Botswana 1960                NaN                 8022.0
#          1961                NaN                 8364.0
#          1962                NaN                 8575.0
#          1963                NaN                 8703.0
#          1964                NaN                 8803.0
#
#                Urban population (% of total population)
# country  date
# Botswana 1960                                       NaN
#          1961                                       NaN
#          1962                                       NaN
#          1963                                       NaN
#          1964                                       NaN
#
# [5 rows x 49 columns]

# %%
# Now we subset for a particular year

wbQueriedAfrica.sort_index(inplace=True)

# What is the total of missing values that there are per year 
for i in range(2013,2019,1):
    print('{} missing values out of {} for year {} '.format(wbQueriedAfrica.xs(str(i),level='date'). 
                                                            transpose().isnull().sum().sum(), # Calculates overall sum of null values
                                                            wbQueriedAfrica.shape[1] * len(wbQueriedAfrica.index.levels[0]), # Number of columns * number of countries = total possible missing values 
                                                            i) # ith year 
        )

# It seems that 2015 is the most non-missing updated info that we can obtain 

# data for 2015 is queried
wbQueriedAfrica2015 = wbQueriedAfrica.xs('2015',level='date')

# Printing the data frame to know the contents
wbQueriedAfrica2015

# saving it to excel
   
wbQueriedAfrica2015.to_excel('worldBank2015AfricaCountries.xlsx')  # This is commented so I don't overwrite by mistake the file
# Out:
# 181 missing values out of 1078 for year 2013
# 333 missing values out of 1078 for year 2014
# 124 missing values out of 1078 for year 2015
# 328 missing values out of 1078 for year 2016
# 338 missing values out of 1078 for year 2017
# 343 missing values out of 1078 for year 2018
